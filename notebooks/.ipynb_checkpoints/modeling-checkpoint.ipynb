# %%
import sys
# Back to the basics - this version worked for you!
# !{sys.executable} -m pip install xgboost shap joblib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [23 lines of output]
#   Traceback (most recent call last):
#     File "C:\ProgramData\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\ProgramData\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import os
import pandas as pd
import sys
import xgboost
import shap

# This allows the notebook to "step out" and see the 'src' folder
sys.path.append('..') 

print(f"XGBoost version: {xgboost.__version__}")
print(f"SHAP version: {shap.__version__}")
print("Navigation and libraries are ready.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 4
#       2 import pandas as pd
#       3 import sys
# ----> 4 import xgboost
#       5 import shap
#       7 # This allows the notebook to "step out" and see the 'src' folder
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %run ../src/prepare_data.py

# %%
# %run ../src/preprocess_data.py

# %%
# %run ../src/train_models.py
